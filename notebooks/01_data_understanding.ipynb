# %% [markdown]
# # 01 — Data Understanding
#
# This notebook loads Amazon's annual segment dataset and validates the structure.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(ROOT))

from src.data_loader import load_raw_data

raw = load_raw_data(ROOT / "data/raw/amazon_segment_annual_2019_2025.csv")
raw.head()

# %%
raw.info()

# %%
raw.groupby("segment")[["net_sales_musd", "operating_income_musd"]].describe()
